# %%
pip install Augmentor sklearn
# Out:
# Requirement already satisfied: Augmentor in d:\anaconda3\envs\551\lib\site-packages (0.2.8)
# Requirement already satisfied: sklearn in d:\anaconda3\envs\551\lib\site-packages (0.0)
# Requirement already satisfied: Pillow>=5.2.0 in d:\anaconda3\envs\551\lib\site-packages (from Augmentor) (7.0.0)
# Requirement already satisfied: numpy>=1.11.0 in d:\anaconda3\envs\551\lib\site-packages (from Augmentor) (1.18.1)
# Requirement already satisfied: future>=0.16.0 in d:\anaconda3\envs\551\lib\site-packages (from Augmentor) (0.18.2)
# Requirement already satisfied: tqdm>=4.9.0 in d:\anaconda3\envs\551\lib\site-packages (from Augmentor) (4.43.0)
# Requirement already satisfied: scikit-learn in d:\anaconda3\envs\551\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied: scipy>=0.17.0 in d:\anaconda3\envs\551\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda3\envs\551\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Hyperparameters
validation_ratio = 0.05
batch_size = 32
learning_rate = 0.001
epochs = 200
path_to_model ="./checkpoints"

# Augmentation hyperparameters
probability_of_transformation = 0.5

# %%
#Load datasets
from keras.datasets import cifar10
import numpy as np

(x_train, digit_y_train), (x_test, digit_y_test) = cifar10.load_data()

# %%
#Data conversion, spliting, and scaling
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

#Scale between 0 and 1
x_train = x_train/255.
x_test = x_test/255.


#Convert labels to one hot encoding
y_train = to_categorical(digit_y_train.flatten(),10)
y_test = to_categorical(digit_y_test.flatten(),10)

# Split data training into sub train and validation
partial_x_train, x_validation, partial_y_train, y_validation = train_test_split(
    x_train, 
    y_train, 
    test_size=validation_ratio, 
    shuffle=True
)

# %%
# Data augmentation pipelines
import Augmentor
from keras.preprocessing.image import ImageDataGenerator

def augmentor_keras_prprocessing_adaptor(pipeline=None):
    '''
    An adpator to solves scaling conversion problem between augmentor library and ImageDataGenerator
    '''
    def __internalOperation(image):
        if pipeline is not None:
            image = pipeline.keras_preprocess_func()(image)
            image = list(image.getdata())
            image = np.array(image)
            image = image.reshape(( int(np.sqrt(image.shape[0])),int(np.sqrt(image.shape[0])),image.shape[1]))
            return image.astype(np.float) / 255.
        return image
    return __internalOperation


# Extra pipeline for augmentation provided by augmentor
pipeline = Augmentor.Pipeline()
pipeline.flip_left_right(probability_of_transformation)
    
# Merge pipeline into keras built-in image augmentation
training_data_generator = ImageDataGenerator(featurewise_center= True,
                                             width_shift_range=0.1, 
                                             height_shift_range=0.1, 
                                             preprocessing_function=augmentor_keras_prprocessing_adaptor(pipeline))
validation_data_generator = ImageDataGenerator(featurewise_center= True)
testing_data_generator = ImageDataGenerator(featurewise_center= True)

#Mean normalize all data based on entire training set
training_data_generator.fit(x_train)
validation_data_generator.fit(x_train)
testing_data_generator.fit(x_train)

# %%
#Fully Connected Neural Network
from keras import models, layers, optimizers, callbacks
import numpy as np

fc_model = models.Sequential()
fc_model.add(layers.InputLayer(input_shape=x_train.shape[1:]))
fc_model.add(layers.Flatten())

fc_model.add(layers.Dense(2500, activation="relu"))
fc_model.add(layers.Dense(2000, activation="relu"))
fc_model.add(layers.Dense(1500, activation="relu"))
fc_model.add(layers.Dense(1000, activation="relu"))
fc_model.add(layers.Dense(500, activation="relu"))

fc_model.add(layers.Dense(10, activation="softmax"))

fc_model.compile(
    optimizer=optimizers.Adam(lr=learning_rate),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

print(fc_model.summary())

fc_model.fit_generator(
    training_data_generator.flow(partial_x_train,partial_y_train,batch_size),
    validation_data = validation_data_generator.flow(x_validation,y_validation,batch_size),
    steps_per_epoch = np.ceil(len(partial_x_train)/batch_size),
    validation_steps = np.ceil(len(x_validation)/batch_size),
    initial_epoch = 0,
    epochs=epochs,
)

result = fc_model.evaluate_generator(
    generator = testing_data_generator.flow(x_test,y_test,batch_size),
    steps = np.ceil(len(x_test)/batch_size)
)
print("Testing loss = ", result[0])
print("Testing accuracy = ", result[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2500)              7682500
# _________________________________________________________________
# dense_15 (Dense)             (None, 2000)              5002000
# _________________________________________________________________
# dense_16 (Dense)             (None, 1500)              3001500
# _________________________________________________________________
# dense_17 (Dense)             (None, 1000)              1501000
# _________________________________________________________________
# dense_18 (Dense)             (None, 500)               500500
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                5010
# =================================================================
# Total params: 17,692,510
# Trainable params: 17,692,510
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1485/1485 [==============================] - 44s 29ms/step - loss: 1.8570 - accuracy: 0.3353 - val_loss: 1.7180 - val_accuracy: 0.4056
# Epoch 2/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.6672 - accuracy: 0.4074 - val_loss: 1.5393 - val_accuracy: 0.4496
# Epoch 3/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.5777 - accuracy: 0.4379 - val_loss: 1.4222 - val_accuracy: 0.4712
# Epoch 4/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.5140 - accuracy: 0.4617 - val_loss: 1.1626 - val_accuracy: 0.4864
# Epoch 5/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.4727 - accuracy: 0.4792 - val_loss: 1.3001 - val_accuracy: 0.4692
# Epoch 6/200
# 1485/1485 [==============================] - 44s 30ms/step - loss: 1.4437 - accuracy: 0.4885 - val_loss: 1.2194 - val_accuracy: 0.5104
# Epoch 7/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.4201 - accuracy: 0.4965 - val_loss: 1.5407 - val_accuracy: 0.5144
# Epoch 8/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.3955 - accuracy: 0.5050 - val_loss: 1.0615 - val_accuracy: 0.5348
# Epoch 9/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.3738 - accuracy: 0.5138 - val_loss: 1.5574 - val_accuracy: 0.5316
# Epoch 10/200
# 1485/1485 [==============================] - 46s 31ms/step - loss: 1.3575 - accuracy: 0.5164 - val_loss: 0.9658 - val_accuracy: 0.5300
# Epoch 11/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.3458 - accuracy: 0.5244 - val_loss: 1.7189 - val_accuracy: 0.5316
# Epoch 12/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.3300 - accuracy: 0.5292 - val_loss: 0.6074 - val_accuracy: 0.5348
# Epoch 13/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.3170 - accuracy: 0.5316 - val_loss: 1.1219 - val_accuracy: 0.5396
# Epoch 14/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.3057 - accuracy: 0.5371 - val_loss: 1.3432 - val_accuracy: 0.5504
# Epoch 15/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2899 - accuracy: 0.5441 - val_loss: 0.5833 - val_accuracy: 0.5572
# Epoch 16/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2794 - accuracy: 0.5477 - val_loss: 1.2014 - val_accuracy: 0.5492
# Epoch 17/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2766 - accuracy: 0.5474 - val_loss: 1.8052 - val_accuracy: 0.5364
# Epoch 18/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2567 - accuracy: 0.5552 - val_loss: 1.6303 - val_accuracy: 0.5612
# Epoch 19/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2474 - accuracy: 0.5591 - val_loss: 1.1490 - val_accuracy: 0.5568
# Epoch 20/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2361 - accuracy: 0.5660 - val_loss: 2.3315 - val_accuracy: 0.5660
# Epoch 21/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2297 - accuracy: 0.5646 - val_loss: 1.0065 - val_accuracy: 0.5664
# Epoch 22/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2187 - accuracy: 0.5678 - val_loss: 2.1130 - val_accuracy: 0.5712
# Epoch 23/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2158 - accuracy: 0.5706 - val_loss: 0.7162 - val_accuracy: 0.5692
# Epoch 24/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.2030 - accuracy: 0.5772 - val_loss: 1.4863 - val_accuracy: 0.5720
# Epoch 25/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1967 - accuracy: 0.5780 - val_loss: 0.9042 - val_accuracy: 0.5696
# Epoch 26/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1901 - accuracy: 0.5809 - val_loss: 1.5008 - val_accuracy: 0.5668
# Epoch 27/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1778 - accuracy: 0.5844 - val_loss: 1.0171 - val_accuracy: 0.5576
# Epoch 28/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1697 - accuracy: 0.5882 - val_loss: 1.3829 - val_accuracy: 0.5756
# Epoch 29/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1657 - accuracy: 0.5857 - val_loss: 0.6283 - val_accuracy: 0.5812
# Epoch 30/200
# 1485/1485 [==============================] - 44s 30ms/step - loss: 1.1571 - accuracy: 0.5919 - val_loss: 1.1186 - val_accuracy: 0.5764
# Epoch 31/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1498 - accuracy: 0.5936 - val_loss: 0.8160 - val_accuracy: 0.5836
# Epoch 32/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1420 - accuracy: 0.5981 - val_loss: 0.6409 - val_accuracy: 0.5796
# Epoch 33/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1415 - accuracy: 0.5999 - val_loss: 1.6088 - val_accuracy: 0.5764
# Epoch 34/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1321 - accuracy: 0.6019 - val_loss: 1.1188 - val_accuracy: 0.5812
# Epoch 35/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1260 - accuracy: 0.6029 - val_loss: 0.9541 - val_accuracy: 0.5948
# Epoch 36/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1181 - accuracy: 0.6069 - val_loss: 1.1558 - val_accuracy: 0.6024
# Epoch 37/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1104 - accuracy: 0.6090 - val_loss: 0.7843 - val_accuracy: 0.5884
# Epoch 38/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0970 - accuracy: 0.6125 - val_loss: 2.4983 - val_accuracy: 0.5812
# Epoch 39/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.1060 - accuracy: 0.6115 - val_loss: 0.8933 - val_accuracy: 0.5872
# Epoch 40/200
# 1485/1485 [==============================] - 44s 29ms/step - loss: 1.0954 - accuracy: 0.6152 - val_loss: 1.0617 - val_accuracy: 0.5956
# Epoch 41/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0915 - accuracy: 0.6192 - val_loss: 1.9002 - val_accuracy: 0.5832
# Epoch 42/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0813 - accuracy: 0.6204 - val_loss: 0.1828 - val_accuracy: 0.5984
# Epoch 43/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0706 - accuracy: 0.6228 - val_loss: 1.1105 - val_accuracy: 0.6024
# Epoch 44/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0745 - accuracy: 0.6227 - val_loss: 0.4665 - val_accuracy: 0.5984
# Epoch 45/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0628 - accuracy: 0.6266 - val_loss: 1.7164 - val_accuracy: 0.6100
# Epoch 46/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0678 - accuracy: 0.6245 - val_loss: 0.5156 - val_accuracy: 0.5948
# Epoch 47/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0584 - accuracy: 0.6315 - val_loss: 2.2516 - val_accuracy: 0.6044
# Epoch 48/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0474 - accuracy: 0.6346 - val_loss: 0.7452 - val_accuracy: 0.6056
# Epoch 49/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0454 - accuracy: 0.6332 - val_loss: 1.0218 - val_accuracy: 0.6064
# Epoch 50/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0327 - accuracy: 0.6387 - val_loss: 2.1947 - val_accuracy: 0.6060
# Epoch 51/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0356 - accuracy: 0.6369 - val_loss: 1.1138 - val_accuracy: 0.6088
# Epoch 52/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0210 - accuracy: 0.6426 - val_loss: 0.2810 - val_accuracy: 0.6080
# Epoch 53/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0201 - accuracy: 0.6437 - val_loss: 2.4339 - val_accuracy: 0.6144
# Epoch 54/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0069 - accuracy: 0.6471 - val_loss: 2.7918 - val_accuracy: 0.6196
# Epoch 55/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 1.0033 - accuracy: 0.6481 - val_loss: 0.6220 - val_accuracy: 0.6232
# Epoch 56/200
# 1485/1485 [==============================] - 44s 30ms/step - loss: 0.9983 - accuracy: 0.6495 - val_loss: 1.5883 - val_accuracy: 0.6176
# Epoch 57/200
# 1485/1485 [==============================] - 44s 29ms/step - loss: 1.0004 - accuracy: 0.6502 - val_loss: 1.1492 - val_accuracy: 0.6084
# Epoch 58/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9933 - accuracy: 0.6540 - val_loss: 0.2856 - val_accuracy: 0.6144
# Epoch 59/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9884 - accuracy: 0.6543 - val_loss: 1.9232 - val_accuracy: 0.6188
# Epoch 60/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9902 - accuracy: 0.6555 - val_loss: 0.4016 - val_accuracy: 0.6292
# Epoch 61/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9901 - accuracy: 0.6545 - val_loss: 0.5474 - val_accuracy: 0.6220
# Epoch 62/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9701 - accuracy: 0.6588 - val_loss: 0.5989 - val_accuracy: 0.5996
# Epoch 63/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9713 - accuracy: 0.6622 - val_loss: 1.7277 - val_accuracy: 0.6116
# Epoch 64/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9925 - accuracy: 0.6600 - val_loss: 0.3714 - val_accuracy: 0.6216
# Epoch 65/200
# 1485/1485 [==============================] - 44s 30ms/step - loss: 0.9596 - accuracy: 0.6646 - val_loss: 1.1438 - val_accuracy: 0.6184
# Epoch 66/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9547 - accuracy: 0.6668 - val_loss: 1.3469 - val_accuracy: 0.6264
# Epoch 67/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9435 - accuracy: 0.6716 - val_loss: 1.6424 - val_accuracy: 0.6156
# Epoch 68/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9761 - accuracy: 0.6634 - val_loss: 2.0429 - val_accuracy: 0.6168
# Epoch 69/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9454 - accuracy: 0.6697 - val_loss: 0.8485 - val_accuracy: 0.6108
# Epoch 70/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9448 - accuracy: 0.6723 - val_loss: 1.9827 - val_accuracy: 0.6168
# Epoch 71/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.9386 - accuracy: 0.6713 - val_loss: 0.6312 - val_accuracy: 0.6176
# Epoch 72/200
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0
# 1485/1485 [==============================] - 43s 29ms/step - loss: 0.6003 - accuracy: 0.7981 - val_loss: 1.7534 - val_accuracy: 0.6264
# Epoch 199/200
# 1485/1485 [==============================] - 44s 29ms/step - loss: 0.6199 - accuracy: 0.7962 - val_loss: 0.9121 - val_accuracy: 0.6200
# Epoch 200/200
# 1485/1485 [==============================] - 44s 30ms/step - loss: 0.5973 - accuracy: 0.8004 - val_loss: 0.2473 - val_accuracy: 0.6284
# Testing loss =  2.0614442825317383
# Testing accuracy =  0.6262000203132629

# %%
from keras import callbacks
import numpy as np
import os
import pathlib

#Helper functions
def get_learning_rate (epoch, lr):
    '''
    Hardset learning rate to be use with learningRateScheduler
    '''
    lr = learning_rate
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    return lr

class ParameterLogger(callbacks.Callback):
    def __init__(self, epochs_file_path, period):
      self.epochs_file_path = epochs_file_path
      self.period = period
      self.counter = 0 

    def on_epoch_end(self, epoch, logs=None):
        self.counter = self.counter + 1
        if( self.counter == self.period):
          self.counter=0
          with open(self.epochs_file_path, 'w') as f:
            k = epoch+1
            f.write(str(k))

# %%
from keras import models, layers, optimizers
import numpy as np
import os
import pathlib

#Build new networks or load existiing one

def build_resnet(filepath):
    '''
    Load existing resnet or create a new one
    '''
    #Create folders for storing weights
    pathlib.Path(os.path.dirname(filepath)).mkdir(parents=True, exist_ok=True)

    #Attempt to load weights checkpoint if it existed
    models_file_path = filepath+".h5"
    epochs_file_path = filepath+".txt"

    model = Resnet()
    epochs = 0

    if(os.path.exists(models_file_path)):
        print('Checkpoint detected.')
        try:
            model.load_weights(models_file_path)
            with open(epochs_file_path, 'r') as f:
              epochs = int(f.read())

            print("Load weights from disks")
        except Exception as e:
            print("Fail to load weights due to wrong models architecture ")

    return model, epochs


def ResnetLayers(previous_layers, filters=128, kernel_size=(3,3), padding='same', strides=1 , activation='relu'):
    #First Conv2D layer
    main_path = layers.Conv2D(filters=filters, kernel_size=kernel_size, padding = padding, strides = strides, kernel_initializer='he_normal')(previous_layers)
    main_path = layers.BatchNormalization()(main_path)
    main_path = layers.Activation(activation)(main_path)
    
    #Second Conv2D layer
    main_path = layers.Conv2D(filters=filters, kernel_size=kernel_size, padding = padding, kernel_initializer='he_normal')(main_path)
    main_path = layers.BatchNormalization()(main_path)  

    #Check if inputs have the right shape to perform addition
    if main_path.shape[1:] == previous_layers.shape[1:]:
        shortcut_path = previous_layers
    else:
        shortcut_path = layers.Conv2D(filters=filters, kernel_size=(1,1), padding = padding, strides = strides, activation= activation, kernel_initializer='he_normal')(previous_layers)

    #Complete the second Conv2D layer
    main_path = layers.Add()([main_path, shortcut_path])
    main_path = layers.Activation(activation)(main_path)
    return main_path


def Resnet():
    inputs = layers.Input(shape= x_train.shape[1:])

    #First layers
    outputs = layers.Conv2D(filters=16, kernel_size=(3,3), padding = 'same', strides = 1, kernel_initializer='he_normal')(inputs)
    outputs = layers.BatchNormalization()(outputs)
    outputs = layers.Activation('relu')(outputs)

    #Stacks 1
    outputs = ResnetLayers(outputs,  filters=16, kernel_size=(3,3), padding='same', strides=1 , activation='relu')
    outputs = ResnetLayers(outputs,  filters=16, kernel_size=(3,3), padding='same', strides=1 , activation='relu')
    outputs = ResnetLayers(outputs,  filters=16, kernel_size=(3,3), padding='same', strides=1 , activation='relu')

    #Stacks 2
    outputs = ResnetLayers(outputs,  filters=32, kernel_size=(3,3), padding='same', strides=2 , activation='relu')
    outputs = ResnetLayers(outputs,  filters=32, kernel_size=(3,3), padding='same', strides=1 , activation='relu')
    outputs = ResnetLayers(outputs,  filters=32, kernel_size=(3,3), padding='same', strides=1 , activation='relu')

    #Stacks 3
    outputs = ResnetLayers(outputs,  filters=64, kernel_size=(3,3), padding='same', strides=2 , activation='relu')
    outputs = ResnetLayers(outputs,  filters=64, kernel_size=(3,3), padding='same', strides=1 , activation='relu')
    outputs = ResnetLayers(outputs,  filters=64, kernel_size=(3,3), padding='same', strides=1 , activation='relu')


    outputs = layers.AveragePooling2D(pool_size=8)(outputs)
    outputs = layers.Flatten()(outputs)
    outputs = layers.Dense(10, activation="softmax", kernel_initializer='he_normal')(outputs)

    model = models.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer=optimizers.Adam(lr=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    return model

# %%
#Convolutional Neural Network
from keras import models, layers, optimizers, callbacks
import numpy as np
import os
import pathlib

#Form  model path 
filespath = os.path.join(path_to_model+"/cnn_model")
        
#Some callbacks
modelCheckpoint = callbacks.ModelCheckpoint(filespath +".h5",save_best_only=True,save_weights_only=True, period=10)
parameterLogger = ParameterLogger(filespath +".txt",  period=10)
learningRateScheduler = callbacks.LearningRateScheduler(get_learning_rate, verbose = 1)
learningReducer = callbacks.ReduceLROnPlateau(factor=np.sqrt(0.5), cooldown=0, patience=3, min_lr=5e-7, verbose=1)

#Load saved weights
cnn_model, initial_epoch = build_resnet(filespath)

#Print model
print(cnn_model.summary())

#Start training
cnn_model.fit_generator(
    training_data_generator.flow(partial_x_train,partial_y_train,batch_size),
    validation_data = validation_data_generator.flow(x_validation,y_validation,batch_size),
    steps_per_epoch = np.ceil(len(partial_x_train)/batch_size),
    validation_steps = np.ceil(len(x_validation)/batch_size),
    initial_epoch = initial_epoch,
    epochs=epochs,
    callbacks=[learningRateScheduler, modelCheckpoint, parameterLogger]
)

#Evaluate test set
result = cnn_model.evaluate_generator(
    generator = testing_data_generator.flow(x_test,y_test,batch_size),
    steps = np.ceil(len(x_test)/batch_size)
)

#Print results
print("Testing loss = ", result[0])
print("Testing accuracy = ", result[1])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 16)   64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 16)   2320        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 16)   64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 16)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 16)   2320        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 16)   64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 16)   0           batch_normalization_22[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 16)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 16)   2320        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 16)   64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 16)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 16)   2320        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 16)   64          conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 16)   0           batch_normalization_24[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 16)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 16)   2320        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 16)   64          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 16)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 16)   2320        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 16)   64          conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 16)   0           batch_normalization_26[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 16)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 32)   4640        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 32)   544         activation_26[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 32)   0           batch_normalization_28[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 32)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 32)   0           batch_normalization_30[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 32)   0           batch_normalization_32[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 64)     18496       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 64)     256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 64)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 64)     36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 64)     256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     2112        activation_32[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 64)     0           batch_normalization_34[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 64)     0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 64)     36928       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 64)     256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 64)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 64)     36928       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 64)     256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 64)     0           batch_normalization_36[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 64)     0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 64)     36928       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 64)     256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 64)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 64)     36928       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 64)     256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 64)     0           batch_normalization_38[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 64)     0           add_18[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 64)     0           activation_38[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 64)           0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           650         flatten_2[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# None
# Epoch 1/200
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 67s 45ms/step - loss: 1.4637 - accuracy: 0.4767 - val_loss: 1.4967 - val_accuracy: 0.5740
# Epoch 2/200
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 62s 42ms/step - loss: 1.0300 - accuracy: 0.6352 - val_loss: 1.5435 - val_accuracy: 0.6312
# Epoch 3/200
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.8660 - accuracy: 0.6956 - val_loss: 0.6659 - val_accuracy: 0.6660
# Epoch 4/200
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.7705 - accuracy: 0.7320 - val_loss: 0.5255 - val_accuracy: 0.7208
# Epoch 5/200
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 62s 42ms/step - loss: 0.6921 - accuracy: 0.7604 - val_loss: 0.6872 - val_accuracy: 0.7268
# Epoch 6/200
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 64s 43ms/step - loss: 0.6386 - accuracy: 0.7804 - val_loss: 0.6375 - val_accuracy: 0.7308
# Epoch 7/200
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.5989 - accuracy: 0.7937 - val_loss: 1.3853 - val_accuracy: 0.7828
# Epoch 8/200
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.5617 - accuracy: 0.8061 - val_loss: 1.1285 - val_accuracy: 0.7436
# Epoch 9/200
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.5317 - accuracy: 0.8181 - val_loss: 0.0479 - val_accuracy: 0.7040
# Epoch 10/200
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.5075 - accuracy: 0.8252 - val_loss: 0.3812 - val_accuracy: 0.7496
# Epoch 11/200
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.4840 - accuracy: 0.8331 - val_loss: 1.2752 - val_accuracy: 0.7880
# Epoch 12/200
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.4589 - accuracy: 0.8412 - val_loss: 0.4034 - val_accuracy: 0.7924
# Epoch 13/200
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.4516 - accuracy: 0.8448 - val_loss: 0.0926 - val_accuracy: 0.8024
# Epoch 14/200
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.4287 - accuracy: 0.8523 - val_loss: 0.6011 - val_accuracy: 0.8036
# Epoch 15/200
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.4136 - accuracy: 0.8567 - val_loss: 0.8277 - val_accuracy: 0.8304
# Epoch 16/200
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.4023 - accuracy: 0.8621 - val_loss: 0.7493 - val_accuracy: 0.7864
# Epoch 17/200
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3895 - accuracy: 0.8661 - val_loss: 0.6641 - val_accuracy: 0.8268
# Epoch 18/200
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3752 - accuracy: 0.8702 - val_loss: 0.4344 - val_accuracy: 0.8028
# Epoch 19/200
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3655 - accuracy: 0.8744 - val_loss: 0.1525 - val_accuracy: 0.7976
# Epoch 20/200
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3500 - accuracy: 0.8795 - val_loss: 0.7191 - val_accuracy: 0.8248
# Epoch 21/200
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3463 - accuracy: 0.8795 - val_loss: 1.4788 - val_accuracy: 0.8268
# Epoch 22/200
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3366 - accuracy: 0.8830 - val_loss: 0.0087 - val_accuracy: 0.8164
# Epoch 23/200
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3215 - accuracy: 0.8881 - val_loss: 1.0577 - val_accuracy: 0.8228
# Epoch 24/200
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3163 - accuracy: 0.8908 - val_loss: 0.0757 - val_accuracy: 0.8424
# Epoch 25/200
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3115 - accuracy: 0.8904 - val_loss: 0.9219 - val_accuracy: 0.8556
# Epoch 26/200
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.3009 - accuracy: 0.8942 - val_loss: 1.9701 - val_accuracy: 0.8380
# Epoch 27/200
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2977 - accuracy: 0.8972 - val_loss: 0.0076 - val_accuracy: 0.8328
# Epoch 28/200
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2866 - accuracy: 0.8999 - val_loss: 0.0512 - val_accuracy: 0.8512
# Epoch 29/200
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 66s 44ms/step - loss: 0.2837 - accuracy: 0.9011 - val_loss: 2.3724 - val_accuracy: 0.8448
# Epoch 30/200
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2751 - accuracy: 0.9048 - val_loss: 0.7001 - val_accuracy: 0.8488
# Epoch 31/200
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2716 - accuracy: 0.9052 - val_loss: 0.5577 - val_accuracy: 0.8636
# Epoch 32/200
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2631 - accuracy: 0.9082 - val_loss: 0.2847 - val_accuracy: 0.8564
# Epoch 33/200
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2627 - accuracy: 0.9084 - val_loss: 2.1656 - val_accuracy: 0.8448
# Epoch 34/200
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2545 - accuracy: 0.9118 - val_loss: 0.2272 - val_accuracy: 0.8696
# Epoch 35/200
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2461 - accuracy: 0.9131 - val_loss: 0.0107 - val_accuracy: 0.8716
# Epoch 36/200
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2445 - accuracy: 0.9143 - val_loss: 0.4284 - val_accuracy: 0.8420
# Epoch 37/200
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2368 - accuracy: 0.9167 - val_loss: 0.0556 - val_accuracy: 0.8512
# Epoch 38/200
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2345 - accuracy: 0.9168 - val_loss: 0.4015 - val_accuracy: 0.8672
# Epoch 39/200
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2301 - accuracy: 0.9187 - val_loss: 0.2239 - val_accuracy: 0.8700
# Epoch 40/200
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2271 - accuracy: 0.9199 - val_loss: 0.1108 - val_accuracy: 0.8788
# Epoch 41/200
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2247 - accuracy: 0.9212 - val_loss: 0.2199 - val_accuracy: 0.8456
# Epoch 42/200
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2185 - accuracy: 0.9231 - val_loss: 0.7505 - val_accuracy: 0.8472
# Epoch 43/200
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2182 - accuracy: 0.9235 - val_loss: 0.9619 - val_accuracy: 0.8524
# Epoch 44/200
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2140 - accuracy: 0.9239 - val_loss: 0.0336 - val_accuracy: 0.8676
# Epoch 45/200
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2069 - accuracy: 0.9266 - val_loss: 0.0555 - val_accuracy: 0.8300
# Epoch 46/200
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.2030 - accuracy: 0.9296 - val_loss: 3.2845 - val_accuracy: 0.8664
# Epoch 47/200
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 39ms/step - loss: 0.1995 - accuracy: 0.9285 - val_loss: 0.2762 - val_accuracy: 0.8720
# Epoch 48/200
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.2002 - accuracy: 0.9288 - val_loss: 0.0243 - val_accuracy: 0.8724
# Epoch 49/200
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1989 - accuracy: 0.9308 - val_loss: 0.0289 - val_accuracy: 0.8600
# Epoch 50/200
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1922 - accuracy: 0.9305 - val_loss: 0.0047 - val_accuracy: 0.8712
# Epoch 51/200
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1886 - accuracy: 0.9337 - val_loss: 0.0289 - val_accuracy: 0.8672
# Epoch 52/200
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1904 - accuracy: 0.9328 - val_loss: 1.0295 - val_accuracy: 0.8400
# Epoch 53/200
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1802 - accuracy: 0.9356 - val_loss: 3.7075e-04 - val_accuracy: 0.8420
# Epoch 54/200
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1832 - accuracy: 0.9348 - val_loss: 0.0911 - val_accuracy: 0.8560
# Epoch 55/200
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1782 - accuracy: 0.9371 - val_loss: 0.2836 - val_accuracy: 0.8484
# Epoch 56/200
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1757 - accuracy: 0.9380 - val_loss: 0.1399 - val_accuracy: 0.8636
# Epoch 57/200
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1712 - accuracy: 0.9391 - val_loss: 0.0779 - val_accuracy: 0.8632
# Epoch 58/200
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1693 - accuracy: 0.9393 - val_loss: 0.0067 - val_accuracy: 0.8752
# Epoch 59/200
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1689 - accuracy: 0.9408 - val_loss: 0.2454 - val_accuracy: 0.8544
# Epoch 60/200
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1681 - accuracy: 0.9414 - val_loss: 0.7924 - val_accuracy: 0.8840
# Epoch 61/200
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1646 - accuracy: 0.9416 - val_loss: 0.0011 - val_accuracy: 0.8748
# Epoch 62/200
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1610 - accuracy: 0.9428 - val_loss: 0.0028 - val_accuracy: 0.8708
# Epoch 63/200
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1563 - accuracy: 0.9439 - val_loss: 0.5440 - val_accuracy: 0.8456
# Epoch 64/200
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 59s 40ms/step - loss: 0.1614 - accuracy: 0.9440 - val_loss: 0.0025 - val_accuracy: 0.8836
# Epoch 65/200
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.1591 - accuracy: 0.9438 - val_loss: 0.0770 - val_accuracy: 0.8788
# Epoch 66/200
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.1523 - accuracy: 0.9454 - val_loss: 1.1956 - val_accuracy: 0.8756
# Epoch 67/200
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.1549 - accuracy: 0.9460 - val_loss: 0.1545 - val_accuracy: 0.8584
# Epoch 68/200
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.1487 - accuracy: 0.9479 - val_loss: 1.7359 - val_accuracy: 0.8728
# Epoch 69/200
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.1490 - accuracy: 0.9467 - val_loss: 0.8741 - val_accuracy: 0.8640
# Epoch 70/200
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 58s 39ms/step - loss: 0.1461 - accuracy: 0.9475 - val_loss: 0.3244 - val_accuracy: 0.8600
# Epoch 71/200
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1427 - accuracy: 0.9489 - val_loss: 0.0288 - val_accuracy: 0.8848
# Epoch 72/200
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1473 - accuracy: 0.9481 - val_loss: 0.2572 - val_accuracy: 0.8864
# Epoch 73/200
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1411 - accuracy: 0.9492 - val_loss: 0.5614 - val_accuracy: 0.8688
# Epoch 74/200
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1408 - accuracy: 0.9488 - val_loss: 1.5621 - val_accuracy: 0.8904
# Epoch 75/200
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1351 - accuracy: 0.9509 - val_loss: 0.0031 - val_accuracy: 0.8848
# Epoch 76/200
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1354 - accuracy: 0.9517 - val_loss: 0.4773 - val_accuracy: 0.8604
# Epoch 77/200
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1355 - accuracy: 0.9513 - val_loss: 0.4838 - val_accuracy: 0.8848
# Epoch 78/200
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1331 - accuracy: 0.9527 - val_loss: 0.1930 - val_accuracy: 0.8672
# Epoch 79/200
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1310 - accuracy: 0.9535 - val_loss: 0.0047 - val_accuracy: 0.8808
# Epoch 80/200
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1327 - accuracy: 0.9525 - val_loss: 0.0836 - val_accuracy: 0.8688
# Epoch 81/200
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.1265 - accuracy: 0.9553 - val_loss: 0.2471 - val_accuracy: 0.8572
# Epoch 82/200
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0953 - accuracy: 0.9662 - val_loss: 0.0029 - val_accuracy: 0.9008
# Epoch 83/200
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0794 - accuracy: 0.9730 - val_loss: 0.0875 - val_accuracy: 0.9052
# Epoch 84/200
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0770 - accuracy: 0.9732 - val_loss: 0.1638 - val_accuracy: 0.9020
# Epoch 85/200
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0743 - accuracy: 0.9734 - val_loss: 2.0167 - val_accuracy: 0.9008
# Epoch 86/200
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0713 - accuracy: 0.9751 - val_loss: 3.6476e-05 - val_accuracy: 0.9020
# Epoch 87/200
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0685 - accuracy: 0.9759 - val_loss: 0.0783 - val_accuracy: 0.9020
# Epoch 88/200
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 58s 39ms/step - loss: 0.0670 - accuracy: 0.9766 - val_loss: 1.2608 - val_accuracy: 0.9036
# Epoch 89/200
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0660 - accuracy: 0.9777 - val_loss: 0.0068 - val_accuracy: 0.9024
# Epoch 90/200
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0640 - accuracy: 0.9781 - val_loss: 0.0605 - val_accuracy: 0.9036
# Epoch 91/200
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0632 - accuracy: 0.9792 - val_loss: 0.6297 - val_accuracy: 0.9036
# Epoch 92/200
#
# Epoch 00092: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0647 - accuracy: 0.9771 - val_loss: 2.4425 - val_accuracy: 0.9048
# Epoch 93/200
#
# Epoch 00093: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0599 - accuracy: 0.9792 - val_loss: 0.7500 - val_accuracy: 0.9032
# Epoch 94/200
#
# Epoch 00094: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0592 - accuracy: 0.9798 - val_loss: 7.7215e-04 - val_accuracy: 0.9060
# Epoch 95/200
#
# Epoch 00095: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0583 - accuracy: 0.9801 - val_loss: 1.0132 - val_accuracy: 0.9060
# Epoch 96/200
#
# Epoch 00096: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0542 - accuracy: 0.9816 - val_loss: 0.1401 - val_accuracy: 0.9028
# Epoch 97/200
#
# Epoch 00097: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0564 - accuracy: 0.9811 - val_loss: 0.7686 - val_accuracy: 0.9040
# Epoch 98/200
#
# Epoch 00098: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0575 - accuracy: 0.9806 - val_loss: 0.0030 - val_accuracy: 0.9020
# Epoch 99/200
#
# Epoch 00099: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0550 - accuracy: 0.9807 - val_loss: 4.7684e-07 - val_accuracy: 0.9080
# Epoch 100/200
#
# Epoch 00100: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0545 - accuracy: 0.9808 - val_loss: 0.0302 - val_accuracy: 0.9040
# Epoch 101/200
#
# Epoch 00101: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0535 - accuracy: 0.9820 - val_loss: 4.5395e-04 - val_accuracy: 0.9036
# Epoch 102/200
#
# Epoch 00102: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0536 - accuracy: 0.9818 - val_loss: 0.0836 - val_accuracy: 0.9036
# Epoch 103/200
#
# Epoch 00103: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0509 - accuracy: 0.9827 - val_loss: 0.4537 - val_accuracy: 0.9048
# Epoch 104/200
#
# Epoch 00104: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0520 - accuracy: 0.9820 - val_loss: 0.9591 - val_accuracy: 0.9040
# Epoch 105/200
#
# Epoch 00105: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0497 - accuracy: 0.9828 - val_loss: 0.0258 - val_accuracy: 0.9060
# Epoch 106/200
#
# Epoch 00106: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 60s 40ms/step - loss: 0.0508 - accuracy: 0.9828 - val_loss: 0.0110 - val_accuracy: 0.9060
# Epoch 107/200
#
# Epoch 00107: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0478 - accuracy: 0.9838 - val_loss: 0.0192 - val_accuracy: 0.9016
# Epoch 108/200
#
# Epoch 00108: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0526 - accuracy: 0.9820 - val_loss: 4.1005e-05 - val_accuracy: 0.9024
# Epoch 109/200
#
# Epoch 00109: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0470 - accuracy: 0.9838 - val_loss: 0.3135 - val_accuracy: 0.9016
# Epoch 110/200
#
# Epoch 00110: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0468 - accuracy: 0.9835 - val_loss: 0.1294 - val_accuracy: 0.9040
# Epoch 111/200
#
# Epoch 00111: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0491 - accuracy: 0.9828 - val_loss: 0.0780 - val_accuracy: 0.9048
# Epoch 112/200
#
# Epoch 00112: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0473 - accuracy: 0.9838 - val_loss: 3.0191 - val_accuracy: 0.9032
# Epoch 113/200
#
# Epoch 00113: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0489 - accuracy: 0.9824 - val_loss: 4.6071 - val_accuracy: 0.9036
# Epoch 114/200
#
# Epoch 00114: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0463 - accuracy: 0.9840 - val_loss: 0.0238 - val_accuracy: 0.9064
# Epoch 115/200
#
# Epoch 00115: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0474 - accuracy: 0.9838 - val_loss: 5.4982e-05 - val_accuracy: 0.9052
# Epoch 116/200
#
# Epoch 00116: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0486 - accuracy: 0.9836 - val_loss: 1.6413 - val_accuracy: 0.9024
# Epoch 117/200
#
# Epoch 00117: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0476 - accuracy: 0.9834 - val_loss: 1.8328e-05 - val_accuracy: 0.9012
# Epoch 118/200
#
# Epoch 00118: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.1995 - val_accuracy: 0.9084
# Epoch 119/200
#
# Epoch 00119: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0457 - accuracy: 0.9836 - val_loss: 2.4791 - val_accuracy: 0.9048
# Epoch 120/200
#
# Epoch 00120: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0469 - accuracy: 0.9835 - val_loss: 0.0728 - val_accuracy: 0.9056
# Epoch 121/200
#
# Epoch 00121: LearningRateScheduler setting learning rate to 0.0001.
# 1485/1485 [==============================] - 60s 40ms/step - loss: 0.0430 - accuracy: 0.9860 - val_loss: 0.0053 - val_accuracy: 0.9028
# Epoch 122/200
#
# Epoch 00122: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0433 - accuracy: 0.9855 - val_loss: 0.0318 - val_accuracy: 0.9060
# Epoch 123/200
#
# Epoch 00123: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0433 - accuracy: 0.9852 - val_loss: 2.1221e-04 - val_accuracy: 0.9068
# Epoch 124/200
#
# Epoch 00124: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0412 - accuracy: 0.9856 - val_loss: 0.0036 - val_accuracy: 0.9060
# Epoch 125/200
#
# Epoch 00125: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0430 - accuracy: 0.9853 - val_loss: 0.0542 - val_accuracy: 0.9064
# Epoch 126/200
#
# Epoch 00126: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0425 - accuracy: 0.9859 - val_loss: 2.4507 - val_accuracy: 0.9056
# Epoch 127/200
#
# Epoch 00127: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0410 - accuracy: 0.9862 - val_loss: 0.0699 - val_accuracy: 0.9040
# Epoch 128/200
#
# Epoch 00128: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0420 - accuracy: 0.9856 - val_loss: 0.0209 - val_accuracy: 0.9040
# Epoch 129/200
#
# Epoch 00129: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0429 - accuracy: 0.9856 - val_loss: 3.2214e-05 - val_accuracy: 0.9048
# Epoch 130/200
#
# Epoch 00130: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0400 - accuracy: 0.9868 - val_loss: 0.6984 - val_accuracy: 0.9040
# Epoch 131/200
#
# Epoch 00131: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 56s 38ms/step - loss: 0.0404 - accuracy: 0.9867 - val_loss: 2.6605e-04 - val_accuracy: 0.9052
# Epoch 132/200
#
# Epoch 00132: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0412 - accuracy: 0.9863 - val_loss: 0.0013 - val_accuracy: 0.9040
# Epoch 133/200
#
# Epoch 00133: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0399 - accuracy: 0.9862 - val_loss: 2.0865 - val_accuracy: 0.9056
# Epoch 134/200
#
# Epoch 00134: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0426 - accuracy: 0.9853 - val_loss: 0.0623 - val_accuracy: 0.9048
# Epoch 135/200
#
# Epoch 00135: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0420 - accuracy: 0.9862 - val_loss: 1.5224 - val_accuracy: 0.9060
# Epoch 136/200
#
# Epoch 00136: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0396 - accuracy: 0.9865 - val_loss: 0.0000e+00 - val_accuracy: 0.9044
# Epoch 137/200
#
# Epoch 00137: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0414 - accuracy: 0.9857 - val_loss: 0.1666 - val_accuracy: 0.9044
# Epoch 138/200
#
# Epoch 00138: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0413 - accuracy: 0.9861 - val_loss: 1.6591e-04 - val_accuracy: 0.9056
# Epoch 139/200
#
# Epoch 00139: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0414 - accuracy: 0.9865 - val_loss: 0.3697 - val_accuracy: 0.9036
# Epoch 140/200
#
# Epoch 00140: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0400 - accuracy: 0.9862 - val_loss: 2.2483 - val_accuracy: 0.9040
# Epoch 141/200
#
# Epoch 00141: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.0528 - val_accuracy: 0.9044
# Epoch 142/200
#
# Epoch 00142: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 60s 41ms/step - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.0731 - val_accuracy: 0.9040
# Epoch 143/200
#
# Epoch 00143: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0383 - accuracy: 0.9868 - val_loss: 0.0011 - val_accuracy: 0.9028
# Epoch 144/200
#
# Epoch 00144: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0381 - accuracy: 0.9874 - val_loss: 1.3755 - val_accuracy: 0.9040
# Epoch 145/200
#
# Epoch 00145: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0407 - accuracy: 0.9863 - val_loss: 0.0019 - val_accuracy: 0.9052
# Epoch 146/200
#
# Epoch 00146: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0389 - accuracy: 0.9873 - val_loss: 0.0092 - val_accuracy: 0.9060
# Epoch 147/200
#
# Epoch 00147: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0397 - accuracy: 0.9866 - val_loss: 0.0035 - val_accuracy: 0.9056
# Epoch 148/200
#
# Epoch 00148: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0398 - accuracy: 0.9862 - val_loss: 0.0170 - val_accuracy: 0.9056
# Epoch 149/200
#
# Epoch 00149: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 0.8328 - val_accuracy: 0.9052
# Epoch 150/200
#
# Epoch 00150: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0389 - accuracy: 0.9870 - val_loss: 0.2621 - val_accuracy: 0.9040
# Epoch 151/200
#
# Epoch 00151: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0389 - accuracy: 0.9868 - val_loss: 7.5035e-04 - val_accuracy: 0.9048
# Epoch 152/200
#
# Epoch 00152: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0420 - accuracy: 0.9855 - val_loss: 0.0026 - val_accuracy: 0.9044
# Epoch 153/200
#
# Epoch 00153: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0396 - accuracy: 0.9863 - val_loss: 0.0146 - val_accuracy: 0.9048
# Epoch 154/200
#
# Epoch 00154: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0411 - accuracy: 0.9854 - val_loss: 5.7847e-04 - val_accuracy: 0.9036
# Epoch 155/200
#
# Epoch 00155: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0389 - accuracy: 0.9862 - val_loss: 0.0226 - val_accuracy: 0.9044
# Epoch 156/200
#
# Epoch 00156: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0395 - accuracy: 0.9865 - val_loss: 0.4228 - val_accuracy: 0.9044
# Epoch 157/200
#
# Epoch 00157: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0378 - accuracy: 0.9872 - val_loss: 0.6845 - val_accuracy: 0.9048
# Epoch 158/200
#
# Epoch 00158: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0385 - accuracy: 0.9865 - val_loss: 0.8173 - val_accuracy: 0.9036
# Epoch 159/200
#
# Epoch 00159: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.0143 - val_accuracy: 0.9032
# Epoch 160/200
#
# Epoch 00160: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0392 - accuracy: 0.9864 - val_loss: 0.1906 - val_accuracy: 0.9060
# Epoch 161/200
#
# Epoch 00161: LearningRateScheduler setting learning rate to 1e-05.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0403 - accuracy: 0.9861 - val_loss: 0.0134 - val_accuracy: 0.9052
# Epoch 162/200
#
# Epoch 00162: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0398 - accuracy: 0.9866 - val_loss: 0.0153 - val_accuracy: 0.9056
# Epoch 163/200
#
# Epoch 00163: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0389 - accuracy: 0.9866 - val_loss: 0.3404 - val_accuracy: 0.9068
# Epoch 164/200
#
# Epoch 00164: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0408 - accuracy: 0.9865 - val_loss: 1.5630e-04 - val_accuracy: 0.9048
# Epoch 165/200
#
# Epoch 00165: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 59s 40ms/step - loss: 0.0371 - accuracy: 0.9874 - val_loss: 4.4703e-07 - val_accuracy: 0.9044
# Epoch 166/200
#
# Epoch 00166: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 39ms/step - loss: 0.0402 - accuracy: 0.9865 - val_loss: 0.9253 - val_accuracy: 0.9060
# Epoch 167/200
#
# Epoch 00167: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0383 - accuracy: 0.9868 - val_loss: 2.2469 - val_accuracy: 0.9044
# Epoch 168/200
#
# Epoch 00168: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0392 - accuracy: 0.9868 - val_loss: 1.1712e-05 - val_accuracy: 0.9040
# Epoch 169/200
#
# Epoch 00169: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0388 - accuracy: 0.9867 - val_loss: 1.1814 - val_accuracy: 0.9060
# Epoch 170/200
#
# Epoch 00170: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0382 - accuracy: 0.9868 - val_loss: 4.4372e-05 - val_accuracy: 0.9048
# Epoch 171/200
#
# Epoch 00171: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0379 - accuracy: 0.9874 - val_loss: 7.1878e-04 - val_accuracy: 0.9056
# Epoch 172/200
#
# Epoch 00172: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0386 - accuracy: 0.9867 - val_loss: 1.7881e-07 - val_accuracy: 0.9040
# Epoch 173/200
#
# Epoch 00173: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0381 - accuracy: 0.9873 - val_loss: 0.3388 - val_accuracy: 0.9048
# Epoch 174/200
#
# Epoch 00174: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0381 - accuracy: 0.9873 - val_loss: 0.6957 - val_accuracy: 0.9064
# Epoch 175/200
#
# Epoch 00175: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0383 - accuracy: 0.9875 - val_loss: 0.2241 - val_accuracy: 0.9064
# Epoch 176/200
#
# Epoch 00176: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0388 - accuracy: 0.9868 - val_loss: 0.0936 - val_accuracy: 0.9052
# Epoch 177/200
#
# Epoch 00177: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0385 - accuracy: 0.9871 - val_loss: 0.0039 - val_accuracy: 0.9052
# Epoch 178/200
#
# Epoch 00178: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0384 - accuracy: 0.9867 - val_loss: 8.4243e-05 - val_accuracy: 0.9044
# Epoch 179/200
#
# Epoch 00179: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0397 - accuracy: 0.9863 - val_loss: 0.1801 - val_accuracy: 0.9052
# Epoch 180/200
#
# Epoch 00180: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0393 - accuracy: 0.9866 - val_loss: 0.0014 - val_accuracy: 0.9060
# Epoch 181/200
#
# Epoch 00181: LearningRateScheduler setting learning rate to 1e-06.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0379 - accuracy: 0.9869 - val_loss: 2.0265e-05 - val_accuracy: 0.9048
# Epoch 182/200
#
# Epoch 00182: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0378 - accuracy: 0.9870 - val_loss: 1.0810e-04 - val_accuracy: 0.9068
# Epoch 183/200
#
# Epoch 00183: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0389 - accuracy: 0.9869 - val_loss: 3.5821e-05 - val_accuracy: 0.9044
# Epoch 184/200
#
# Epoch 00184: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0390 - accuracy: 0.9867 - val_loss: 0.1787 - val_accuracy: 0.9060
# Epoch 185/200
#
# Epoch 00185: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0374 - accuracy: 0.9875 - val_loss: 0.0027 - val_accuracy: 0.9048
# Epoch 186/200
#
# Epoch 00186: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0375 - accuracy: 0.9876 - val_loss: 1.1111 - val_accuracy: 0.9052
# Epoch 187/200
#
# Epoch 00187: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0390 - accuracy: 0.9872 - val_loss: 2.7559 - val_accuracy: 0.9044
# Epoch 188/200
#
# Epoch 00188: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0393 - accuracy: 0.9872 - val_loss: 3.8144e-05 - val_accuracy: 0.9052
# Epoch 189/200
#
# Epoch 00189: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0393 - accuracy: 0.9868 - val_loss: 5.7520e-04 - val_accuracy: 0.9072
# Epoch 190/200
#
# Epoch 00190: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0364 - accuracy: 0.9876 - val_loss: 4.7684e-07 - val_accuracy: 0.9052
# Epoch 191/200
#
# Epoch 00191: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 61s 41ms/step - loss: 0.0389 - accuracy: 0.9871 - val_loss: 0.0077 - val_accuracy: 0.9052
# Epoch 192/200
#
# Epoch 00192: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 60s 40ms/step - loss: 0.0388 - accuracy: 0.9872 - val_loss: 0.0565 - val_accuracy: 0.9056
# Epoch 193/200
#
# Epoch 00193: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0376 - accuracy: 0.9875 - val_loss: 1.2143 - val_accuracy: 0.9060
# Epoch 194/200
#
# Epoch 00194: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0385 - accuracy: 0.9867 - val_loss: 2.6864 - val_accuracy: 0.9040
# Epoch 195/200
#
# Epoch 00195: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0396 - accuracy: 0.9864 - val_loss: 0.0397 - val_accuracy: 0.9056
# Epoch 196/200
#
# Epoch 00196: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0398 - accuracy: 0.9865 - val_loss: 0.0821 - val_accuracy: 0.9056
# Epoch 197/200
#
# Epoch 00197: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 56s 38ms/step - loss: 0.0370 - accuracy: 0.9875 - val_loss: 0.6154 - val_accuracy: 0.9056
# Epoch 198/200
#
# Epoch 00198: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0394 - accuracy: 0.9864 - val_loss: 0.6777 - val_accuracy: 0.9044
# Epoch 199/200
#
# Epoch 00199: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0385 - accuracy: 0.9867 - val_loss: 0.0029 - val_accuracy: 0.9068
# Epoch 200/200
#
# Epoch 00200: LearningRateScheduler setting learning rate to 5e-07.
# 1485/1485 [==============================] - 57s 38ms/step - loss: 0.0382 - accuracy: 0.9869 - val_loss: 3.8264e-04 - val_accuracy: 0.9064
# Testing loss =  0.8170425295829773
# Testing accuracy =  0.9075999855995178

# %%
#Visualization Hyperparameters

#Color options
colors= ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds']

#Image to apply features map onto
img = x_train[0]

#Maximum numbers of images per layers for each visualization
image_cap = 14

# %%
#Visualize Filters

#Imports
import matplotlib.pyplot as plt
import numpy as np

#Helper functions to convert between 1d coordinate and 2d coordinate
def index_to_2d_index (v, width):
    column = v % width
    row = v / width 
    return int(row), int(column)

def two_d_index_to_index(row, column, width):
    return column + (row * width)


#Loop throughts all layers and identify conv2d layers
for layer in cnn_model.layers:
    if 'conv' in layer.name:
        
        #Set internal counter for maximum images per layers
        cap_per_layers = image_cap
        
        #Extract weights and bias
        weights, bias = layer.get_weights()
        kernel_height, kernel_width, num_channels, num_kernels = weights.shape
        
        #Determine a minimum numbers of images slots requires per layers
        width = 7
        height = min(int(np.ceil(num_channels*num_kernels/width)),int(np.ceil(cap_per_layers/width)))
        
        #Set image settings
        fig, axs = plt.subplots(height, width, figsize=(15,2.5*height), squeeze = False)
        fig.suptitle(layer.name, fontsize=20)
        fig.subplots_adjust(top=(height/80)*0.03+0.95)
        
        color_index = np.random.randint(len(colors))
        
        #Start drawing
        for j in range(num_kernels):
            for i in range(num_channels):
                
                #Determines which index to draw at
                index = i + j * num_channels
                
                #Convert to images slots 2d coordinate
                row,column = index_to_2d_index(index,width)
                
                #Draw images
                axs[row,column].imshow(weights[:,:,i,j], cmap=colors[color_index])
                axs[row,column].set_axis_off()
                
                #Update internal image counter
                cap_per_layers = cap_per_layers -1 
                if cap_per_layers<=0:
                    break
            if cap_per_layers<=0:
                    break
        
        #Remove extra image slots that weren't use
        for k in range(1+i + j * num_channels, width*height):
            row,column = index_to_2d_index(k,width)
            fig.delaxes(axs[row][column])
plt.show()
# Out:
# D:\Anaconda3\envs\551\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
#Visualize Features

#Imports
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Model

#Helper functions to convert between 1d coordinate and 2d coordinate
def index_to_2d_index (v, width):
    column = v % width
    row = v / width 
    return int(row), int(column)

def two_d_index_to_index(row, column, width):
    return column + (row * width)

#Extract information from orignal models
names=[]
outputs = []
for layer in cnn_model.layers:
    if  'conv' in layer.name:
        names.append(layer.name)
        outputs.append(layer.output)

#Create new model with multiple outputs        
feature_maps_model = Model(inputs = cnn_model.inputs, outputs = outputs) 

#Use new model to predict an images
result = feature_maps_model.predict(np.array([img]))

if len(outputs) ==1:
    result = [result]

#Loop through output from each convolution layer
for index in range(len(outputs)):
    
    #Set internal counter for maximum images per layers
    cap_per_layers = image_cap
    
    #Reshaping output and extract information
    result[index] = np.squeeze(result[index],axis = 0)

    output_width, output_height, num_kernels = result[index].shape
    
    #Determine a minimum numbers of images slots requires per layers
    width = 7
    height = min(int(np.ceil(num_kernels/width)),int(np.ceil(cap_per_layers/width)))
    
    #Set image settings
    fig, axs = plt.subplots(height, width, figsize=(15,2.5*height), squeeze = False)
    fig.suptitle(names[index], fontsize=20)
    fig.subplots_adjust(left=None, bottom=None, right=None, top=(height/80)*0.03+0.95, wspace=None, hspace=None)
    
    color_index = np.random.randint(len(colors))
    
    #Start drawing
    for i in range(num_kernels):
        
        #Convert to images slots 2d coordinate
        row,column = index_to_2d_index(i,width) 
        
        #Draw images
        axs[row,column].imshow(result[index][:,:,i], cmap=colors[color_index])
        axs[row,column].set_axis_off()
        
        #Update counter
        cap_per_layers = cap_per_layers - 1
        if cap_per_layers<=0:
            break
    #Remove extra image slots that weren't use
    for k in range(i+1, width*height):
        row,column = index_to_2d_index(k,width)
        fig.delaxes(axs[row][column])

plt.show()
# Out:
# D:\Anaconda3\envs\551\lib\site-packages\ipykernel_launcher.py:50: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
