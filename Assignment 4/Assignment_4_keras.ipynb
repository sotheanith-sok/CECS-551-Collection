# %%
import numpy as np
from keras import optimizers

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,0])

from keras import models
from keras import layers

model = models.Sequential() 
model.add(layers.Dense(2, activation='tanh'))
model.add(layers.Dense(1, activation='sigmoid'))
sgd = optimizers.SGD(lr=0.1)
model.compile(optimizer=sgd, loss='binary_crossentropy')
model.fit(X, y, epochs=100000000, batch_size=1, verbose=0)
model.predict_proba(X)

# %%
import numpy as np

class MyModel:
  def __init__(self):
    self.weight_1 = np.random.rand(3,5) 
    self.weight_2 = np.random.rand(2,1)
    self.bias_1 = np.random.rand(2,1)
    self.bias_2 = np.random.rand(1,1) 
    
    pass
  def fit(self, X=None, y=None, epochs=10, batch_size=1):
    pass
  def forward(self):
    pass
  def backward(self):
    pass

model = MyModel()
model.fit()
